# %%
# pandas is a data manipulation library - we import it as pd by convention
import pandas as pd
# matplotlib is for creating visualizations - we import pyplot as plt by convention
import matplotlib.pyplot as plt
# read
_
csv() is a pandas function that loads data from a CSV file into a DataFrame
df = pd.read
_
csv('Pandas
Lesson
_
_
Grades.csv')

# Display first 5 rows
print("First 5 rows:")
print(df.head())
# Display basic information about the DataFrame
print("\nDataFrame information:")
print(df.info())
# Display summary statistics
print("\nSummary statistics:")
print(df.describe())
# Out:
#   Cell In[1], line 10
#     csv('Pandas
#         ^
# SyntaxError: unterminated string literal (detected at line 10)

# %%
# Select a single column using square brackets
primary_
answers = df['# Pri. Ans.']
print("Primary answers column:")
print(primary_
answers.head()) # What does this show?
_____
# Select multiple columns using a list of column names
selected
_
columns = df[['Primary Key A'
,
'# Correct'
,
'% Correct']]
print("\nSelected columns:")
print(selected
_
columns.head()) # What does this show?
_____
# Basic statistics for numeric columns
numeric
_
stats = df['# Correct'].describe()
print("\nStatistics for # Correct:")
print(numeric
_
stats) # List three statistics you see:
_____, _____,
_____

# %%
# Select a single column using square brackets
primary_
answers = df['# Pri. Ans.
']
print("Primary answers column:")
print(primary_
answers.head()) # What does this show?
_____
# Select multiple columns using a list of column names
selected
_
columns = df[['Primary Key A'
,
'# Correct'
,
'% Correct']]
print("\nSelected columns:")
print(selected
_
columns.head()) # What does this show?
_____
# Basic statistics for numeric columns
numeric
_
stats = df['# Correct'].describe()
print("\nStatistics for # Correct:")
print(numeric
_
stats)

# %%
# mean() calculates the average of a numeric column
average
_
correct = df['# Correct'].mean()
print(f"Average number correct: {average
_
correct}")
# value
_
counts() shows frequency of unique values
answer
_
distribution = df['# Pri. Ans.
'].value
_
print("\nDistribution of primary answers:")
print(answer
_
distribution)
counts()
# Your turn - calculate these statistics:
median
_
correct = df['# Correct'].
____() max
_
correct = df['# Correct'].
____() min
_
correct = df['# Correct'].
____()

# %%
# Boolean conditions create a Series of True/False values
high
correct
_
_
mask = df['# Correct'] > 5
print("Boolean mask:")
print(high
correct
_
_
mask.head())
# Use the mask to filter the DataFrame
high
correct
_
_questions = df[high
correct
_
_
mask]
print("\nQuestions with more than 5 correct answers:")
print(high
correct
_
_questions[['Primary Key A'
,
'# Correct']])
# Your turn - create filters for:
# Questions where 'A' was the primary answer
a
_questions = df[df['# Pri. Ans.
'] ==
____]
# Questions with more than 50% correct (hint: use '% Correct' column)
high
_percentage = df[df['% Correct'] >
____]
